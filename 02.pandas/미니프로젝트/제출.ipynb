# %% [markdown]
# # 미니프로젝트

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1)CCTV 데이터 정리하기

# %%
#데이터 파일 읽기
cctv = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_211231기준.csv', encoding='EUC-KR',skiprows=1)
cctv.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0    계  83,557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1  종로구   1,715      815    NaN    NaN    195    150      0     261      85
# 2  중 구   2,447       16    114     87     77    236    240     372     386
# 3  용산구   2,611       34     71    234    125    221    298     351     125
# 4  성동구   3,829      163    144    208    107    325    255     967     415
#
#     2019년   2020년  2021년
# 0  12,267  11,247  7,904
# 1       9     200      0
# 2     155     361    403
# 3     307     617    228
# 4     490     472    283

# %%
#Null data 확인하기
cctv.isna().sum()
# Out:
# 구분          0
# 총계          0
# 2012년 이전    0
# 2012년       1
# 2013년       1
# 2014년       0
# 2015년       0
# 2016년       0
# 2017년       0
# 2018년       0
# 2019년       0
# 2020년       0
# 2021년       0
# dtype: int64

# %%
#Null값 0으로 대체하기
cctv.fillna('0',inplace=True)

# %%
#1000단위 구분기호 없애고 정수로 변환하기
for column in cctv.columns[1:]:
    cctv[column] = cctv[column].str.replace(',','').astype(int)

# %%
#2021년을 제외한 최근 3개년간의 CCTV 증가율 구하기
a = cctv.loc[:,['2012년','2013년','2014년','2015년','2016년','2017년']].sum(axis=1)
b = cctv.loc[:,['2018년','2019년','2020년']].sum(axis=1)*100
cctv['최근증가율'] = b/a
cctv.head()
# Out:
#     구분     총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  83557      4812   1851   3434   4295   6840   8708  11572  10627
# 1  종로구   1715       815      0      0    195    150      0    261     85
# 2  중 구   2447        16    114     87     77    236    240    372    386
# 3  용산구   2611        34     71    234    125    221    298    351    125
# 4  성동구   3829       163    144    208    107    325    255    967    415
#
#    2019년  2020년  2021년      최근증가율
# 0  12267  11247   7904  93.027248
# 1      9    200      0  48.514851
# 2    155    361    403  80.106572
# 3    307    617    228  80.692308
# 4    490    472    283  68.644068

# %%
cctv['2017년이전2']=cctv.iloc[:,2:9].sum(axis=1)

# %%
#구분, 총계, 최근증가율 커럼만 추출하고 컬럼명을 구별, cctv댓수로 변경하기
df = cctv[['구분','총계','최근증가율']]
df.rename(columns={'구분':'구별','총계':'cctv댓수'}, inplace=True)
df.head()
# Out:
#     구별  cctv댓수      최근증가율
# 0    계   83557  93.027248
# 1  종로구    1715  48.514851
# 2  중 구    2447  80.106572
# 3  용산구    2611  80.692308
# 4  성동구    3829  68.644068

# %%
#구 이름에서 공백 지우기
df['구별'] = df['구별'].str.replace(' ', '')
df.head()
# Out:
#     구별  cctv댓수      최근증가율
# 0    계   83557  93.027248
# 1  종로구    1715  48.514851
# 2   중구    2447  80.106572
# 3  용산구    2611  80.692308
# 4  성동구    3829  68.644068

# %%
#첫번째 행(계) 지우기
df.drop(0, inplace=True)
df.head()
# Out:
#     구별  cctv댓수       최근증가율
# 1  종로구    1715   48.514851
# 2   중구    2447   80.106572
# 3  용산구    2611   80.692308
# 4  성동구    3829   68.644068
# 5  광진구    3211  115.654405

# %% [markdown]
# ## 2)인구 데이터 정리하기

# %%
#데이터 파일 읽기
pop = pd.read_table('서울시인구.txt',skiprows=2)
pop.head()
# Out:
#      기간  자치구         세대          계         남자         여자        계.1  \
# 0  2021   합계  4,426,007  9,736,027  4,721,977  5,014,050  9,509,458
# 1  2021  종로구     73,494    153,789     74,186     79,603    144,683
# 2  2021   중구     63,519    131,787     64,083     67,704    122,499
# 3  2021  용산구    111,036    237,285    115,085    122,200    222,953
# 4  2021  성동구    134,233    292,672    142,259    150,413    285,990
#
#         남자.1       여자.1      계.2     남자.2     여자.2  세대당인구   65세이상고령자
# 0  4,618,040  4,891,418  226,569  103,937  122,632   2.15  1,605,416
# 1     70,183     74,500    9,106    4,003    5,103   1.97     27,818
# 2     59,630     62,869    9,288    4,453    4,835   1.93     24,392
# 3    107,210    115,743   14,332    7,875    6,457   2.01     39,070
# 4    139,380    146,610    6,682    2,879    3,803   2.13     46,380

# %%
#Null data 있는지 확인하기
pop.isna().sum()
# Out:
# 기간          0
# 자치구         0
# 세대          0
# 계           0
# 남자          0
# 여자          0
# 계.1         0
# 남자.1        0
# 여자.1        0
# 계.2         0
# 남자.2        0
# 여자.2        0
# 세대당인구       0
# 65세이상고령자    0
# dtype: int64

# %%
#'자치구','계','계.1','계.2','65세이상고령자‘ 컬럼만 추출하고
df2 = pop[['자치구','계','계.1','계.2','65세이상고령자']]
df2.head()
# Out:
#    자치구          계        계.1      계.2   65세이상고령자
# 0   합계  9,736,027  9,509,458  226,569  1,605,416
# 1  종로구    153,789    144,683    9,106     27,818
# 2   중구    131,787    122,499    9,288     24,392
# 3  용산구    237,285    222,953   14,332     39,070
# 4  성동구    292,672    285,990    6,682     46,380

# %%
# 이름을 '구별','인구수','내국인','외국인','고령자'로 변경
df2.columns = ['구별','인구수','내국인','외국인','고령자']
df2.head()
# Out:
#     구별        인구수        내국인      외국인        고령자
# 0   합계  9,736,027  9,509,458  226,569  1,605,416
# 1  종로구    153,789    144,683    9,106     27,818
# 2   중구    131,787    122,499    9,288     24,392
# 3  용산구    237,285    222,953   14,332     39,070
# 4  성동구    292,672    285,990    6,682     46,380

# %%
#1000단위 기호, 정수
for column in df2.columns[1:]:
    df2[column] = df2[column].str.replace(',','').astype(int)

# %%
#첫번째 행 지우기
df2.drop(0,inplace=True)
df2.head()
# Out:
#     구별     인구수     내국인    외국인    고령자
# 1  종로구  153789  144683   9106  27818
# 2   중구  131787  122499   9288  24392
# 3  용산구  237285  222953  14332  39070
# 4  성동구  292672  285990   6682  46380
# 5  광진구  352627  339996  12631  51723

# %%
#'외국인비율'과'고령자비율'컬럼만들기
df2['외국인비율'] = (df2.외국인/df2.인구수*100).round(2)
df2['고령자비율'] = np.round(df2.고령자/df2.인구수*100, 2)
df2.head()
# Out:
#     구별     인구수     내국인    외국인    고령자  외국인비율  고령자비율
# 1  종로구  153789  144683   9106  27818   5.92  18.09
# 2   중구  131787  122499   9288  24392   7.05  18.51
# 3  용산구  237285  222953  14332  39070   6.04  16.47
# 4  성동구  292672  285990   6682  46380   2.28  15.85
# 5  광진구  352627  339996  12631  51723   3.58  14.67

# %% [markdown]
# ## CCTV데이터와 인구 데이터 합치고 저장하기

# %%
df.head()
# Out:
#     구별  cctv댓수       최근증가율
# 1  종로구    1715   48.514851
# 2   중구    2447   80.106572
# 3  용산구    2611   80.692308
# 4  성동구    3829   68.644068
# 5  광진구    3211  115.654405

# %%
df2.head()
# Out:
#     구별     인구수     내국인    외국인    고령자  외국인비율  고령자비율
# 1  종로구  153789  144683   9106  27818   5.92  18.09
# 2   중구  131787  122499   9288  24392   7.05  18.51
# 3  용산구  237285  222953  14332  39070   6.04  16.47
# 4  성동구  292672  285990   6682  46380   2.28  15.85
# 5  광진구  352627  339996  12631  51723   3.58  14.67

# %%
# 데이터 합치기
cctv_pop = pd.merge(df,df2)
cctv_pop.head()
# Out:
#     구별  cctv댓수       최근증가율     인구수     내국인    외국인    고령자  외국인비율  고령자비율
# 0  종로구    1715   48.514851  153789  144683   9106  27818   5.92  18.09
# 1   중구    2447   80.106572  131787  122499   9288  24392   7.05  18.51
# 2  용산구    2611   80.692308  237285  222953  14332  39070   6.04  16.47
# 3  성동구    3829   68.644068  292672  285990   6682  46380   2.28  15.85
# 4  광진구    3211  115.654405  352627  339996  12631  51723   3.58  14.67

# %%
#‘구별’ 컬럼을 인덱스로 만들기
cctv_pop.set_index('구별', inplace=True)
cctv_pop.head()
# Out:
#      cctv댓수       최근증가율     인구수     내국인    외국인    고령자  외국인비율  고령자비율
# 구별
# 종로구    1715   48.514851  153789  144683   9106  27818   5.92  18.09
# 중구     2447   80.106572  131787  122499   9288  24392   7.05  18.51
# 용산구    2611   80.692308  237285  222953  14332  39070   6.04  16.47
# 성동구    3829   68.644068  292672  285990   6682  46380   2.28  15.85
# 광진구    3211  115.654405  352627  339996  12631  51723   3.58  14.67

# %%
# 합친 데이터를 cctv_pop.csv로 저장하기
cctv_pop.to_csv('cctv_pop.csv')
